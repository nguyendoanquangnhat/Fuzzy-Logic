# %%
#1. CREATE A DATAFRAME

# %%
# load library
import pandas as pd
# create dataframe
dataframe = pd.DataFrame()
# add columns
dataframe['Name'] = ['Lemon','Apple','Banana']
dataframe['Price'] = [5,8,7]
dataframe['License'] = [False, True, True]
# show data
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
df = dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
df.describe()
# Out:
#           Price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
df.loc[(df.Price == 5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price == 5) | (df.Name == 'Banana')]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 2  Banana      7     True

# %%
df.loc[(df.Price == 5) | (df.Name == 'Banana') , ('Name', 'Price')]
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
df.iloc[2]
# Out:
# Name       Banana
# Price           7
# License      True
# Name: 2, dtype: object

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:2]
# Out:
#     Name  Price  License
# 0  Lemon      5    False
# 1  Apple      8     True

# %%
df.iloc[0:2,-2]
# Out:
# 0    5
# 1    8
# Name: Price, dtype: int64

# %%
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
df.iloc[0:2,0:-3]
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
sum = df.Price.sum()
print(sum)
# Out:
# 20

# %%
max = df.Price.max()
print(max)
# Out:
# 8

# %%
count = df.Price.count()
print(count)
# Out:
# 3

# %%
# create row data
new = pd.Series(['Orange',10,True], index=['Name','Price','License'])
# append row
dataframe.append(new, ignore_index=True)
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True     SING
# 3  Orange     10     True      NaN

# %%
# append column
dataframe['Location'] = ['USA','VN','SING']
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True     SING

# %%
# remove row
dataframe.drop(1, axis=0).head(5)
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 2  Banana      7     True     SING

# %%
# remove column
dataframe.drop('Location', axis=1).head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
# replace
dataframe['Price'].replace(5,7).head()
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
# rename column
dataframe.rename(columns = {'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     8     True       VN
# 2  Banana     7     True     SING

# %%
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True     SING

# %%
# load library
import pandas as pd
# create url
url = 'http://winterolympicsmedals.com/medals.csv'
# load data
dataframe = pd.read_csv(url)
# show data
dataframe.head(10)
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# 8            M  Silver
# 9            M    Gold

# %%
data = dataframe
data.shape
# Out:
# (2311, 8)

# %%
data.describe()
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
df.head(5)
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
df.iloc[0]
# Out:
# Year                      1924
# City                  Chamonix
# Sport                  Skating
# Discipline      Figure skating
# NOC                        AUT
# Event               individual
# Event gender                 M
# Medal                   Silver
# Name: 0, dtype: object

# %%
df.iloc[3]
# Out:
# Year                 1924
# City             Chamonix
# Sport           Bobsleigh
# Discipline      Bobsleigh
# NOC                   BEL
# Event            four-man
# Event gender            M
# Medal              Bronze
# Name: 3, dtype: object

# %%
df.loc[(df.Medal == 'Gold')]
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 7     1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9     1924  Chamonix     Skating   Speed skating  FIN            1500m
# ...    ...       ...         ...             ...  ...              ...
# 2301  2006     Turin      Skiing   Alpine Skiing  USA  Alpine combined
# 2302  2006     Turin      Skiing   Alpine Skiing  USA     giant slalom
# 2305  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender Medal
# 1               W  Gold
# 2               X  Gold
# 4               M  Gold
# 7               M  Gold
# 9               M  Gold
# ...           ...   ...
# 2301            M  Gold
# 2302            W  Gold
# 2305            M  Gold
# 2307            W  Gold
# 2309            M  Gold
#
# [774 rows x 8 columns]

# %%
mg = df.loc[(df.Medal == 'Gold'),['Medal']]
print(mg.count())
# Out:
# Medal    774
# dtype: int64

# %%
data.iloc[[200,]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# 200  Gold

# %%
data = data.set_index(data['NOC'])
data.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# GER               four-man            M  Bronze
# GER             ice hockey            M  Bronze
# GER             individual            M  Silver
# GER                  pairs            X    Gold
# ..                     ...          ...     ...
# GER           sprint 1.5km            W  Silver
# GER             Individual            M    Gold
# GER      Individual sprint            M  Bronze
# GER                   Team            M  Silver
# GER  Giant parallel slalom            W  Silver
#
# [158 rows x 8 columns]

# %%
data[(data['Year']>=1980) & (data['Medal']=='Gold')]
# Out:
#      Year         City    Sport      Discipline  NOC                  Event  \
# NOC
# AUT  1980  Lake Placid   Skiing   Alpine Skiing  AUT               downhill
# AUT  1980  Lake Placid   Skiing   Alpine Skiing  AUT               downhill
# AUT  1980  Lake Placid   Skiing     Ski Jumping  AUT   K90 individual (70m)
# FIN  1980  Lake Placid   Skiing     Ski Jumping  FIN  K120 individual (90m)
# GBR  1980  Lake Placid  Skating  Figure skating  GBR             individual
# ..    ...          ...      ...             ...  ...                    ...
# USA  2006        Turin   Skiing   Alpine Skiing  USA        Alpine combined
# USA  2006        Turin   Skiing   Alpine Skiing  USA           giant slalom
# USA  2006        Turin   Skiing       Snowboard  USA              Half-pipe
# USA  2006        Turin   Skiing       Snowboard  USA              Half-pipe
# USA  2006        Turin   Skiing       Snowboard  USA        Snowboard Cross
#
#     Event gender Medal
# NOC
# AUT            M  Gold
# AUT            W  Gold
# AUT            M  Gold
# FIN            M  Gold
# GBR            M  Gold
# ..           ...   ...
# USA            M  Gold
# USA            W  Gold
# USA            M  Gold
# USA            W  Gold
# USA            M  Gold
#
# [474 rows x 8 columns]

# %%
data['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
data['Sport'].unique()
# Out:
# array(['Skating', 'Bobsleigh', 'Ice Hockey', 'Biathlon', 'Skiing',
#        'Curling', 'Luge'], dtype=object)

# %%
data = pd.read_csv(url)
data.groupby('NOC').head(5)
# Out:
#       Year      City       Sport       Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT       individual
# 1     1924  Chamonix     Skating   Figure skating  AUT       individual
# 2     1924  Chamonix     Skating   Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...              ...  ...              ...
# 2129  2006     Turin      Skiing  Cross Country S  EST             15km
# 2202  2006     Turin        Luge             Luge  LAT          singles
# 2269  2006     Turin      Skiing        Snowboard  SVK  Snowboard Cross
# 2284  2006     Turin    Biathlon         Biathlon  UKR            7.5km
# 2285  2006     Turin     Skating   Figure skating  UKR      ice dancing
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# 4               M    Gold
# ...           ...     ...
# 2129            M    Gold
# 2202            M  Bronze
# 2269            M  Silver
# 2284            W  Bronze
# 2285            X  Bronze
#
# [190 rows x 8 columns]

# %%
data.groupby('Discipline').count()
# Out:
#                  Year  City  Sport  NOC  Event  Event gender  Medal
# Discipline
# Alpine Skiing     367   367    367  367    367           367    367
# Biathlon          162   162    162  162    162           162    162
# Bobsleigh         115   115    115  115    115           115    115
# Cross Country S   399   399    399  399    399           399    399
# Curling            21    21     21   21     21            21     21
# Figure skating    207   207    207  207    207           207    207
# Freestyle Ski.     54    54     54   54     54            54     54
# Ice Hockey         69    69     69   69     69            69     69
# Luge              108   108    108  108    108           108    108
# Nordic Combined    84    84     84   84     84            84     84
# Short Track S.     96    96     96   96     96            96     96
# Skeleton           18    18     18   18     18            18     18
# Ski Jumping       114   114    114  114    114           114    114
# Snowboard          42    42     42   42     42            42     42
# Speed skating     455   455    455  455    455           455    455

# %%
def uppercase(x):
  return x.upper()
data['Event'].apply(uppercase)[0:10]
# Out:
# 0         INDIVIDUAL
# 1         INDIVIDUAL
# 2              PAIRS
# 3           FOUR-MAN
# 4         ICE HOCKEY
# 5    MILITARY PATROL
# 6              PAIRS
# 7             10000M
# 8             10000M
# 9              1500M
# Name: Event, dtype: object

# %%
data.loc['HUN']
# Out:
#      Year                    City    Sport      Discipline  NOC        Event  \
# NOC
# HUN  1932             Lake Placid  Skating  Figure skating  HUN        pairs
# HUN  1936  Garmisch-Partenkirchen  Skating  Figure skating  HUN        pairs
# HUN  1948              St. Moritz  Skating  Figure skating  HUN        pairs
# HUN  1952                    Oslo  Skating  Figure skating  HUN        pairs
# HUN  1956       Cortina d'Ampezzo  Skating  Figure skating  HUN        pairs
# HUN  1980             Lake Placid  Skating  Figure skating  HUN  ice dancing
#
#     Event gender   Medal
# NOC
# HUN            X  Bronze
# HUN            X  Bronze
# HUN            X  Silver
# HUN            X  Bronze
# HUN            X  Bronze
# HUN            X  Silver

# %%
data[data['NOC']=='FIN'].head(10)
# Out:
#      Year      City     Sport      Discipline  NOC                Event  \
# NOC
# FIN  1924  Chamonix  Biathlon        Biathlon  FIN      military patrol
# FIN  1924  Chamonix   Skating  Figure skating  FIN                pairs
# FIN  1924  Chamonix   Skating   Speed skating  FIN               10000m
# FIN  1924  Chamonix   Skating   Speed skating  FIN               10000m
# FIN  1924  Chamonix   Skating   Speed skating  FIN                1500m
# FIN  1924  Chamonix   Skating   Speed skating  FIN                5000m
# FIN  1924  Chamonix   Skating   Speed skating  FIN                5000m
# FIN  1924  Chamonix   Skating   Speed skating  FIN                 500m
# FIN  1924  Chamonix   Skating   Speed skating  FIN  combined (4 events)
# FIN  1924  Chamonix   Skating   Speed skating  FIN  combined (4 events)
#
#     Event gender   Medal
# NOC
# FIN            M  Silver
# FIN            X  Silver
# FIN            M    Gold
# FIN            M  Silver
# FIN            M    Gold
# FIN            M    Gold
# FIN            M  Silver
# FIN            M  Bronze
# FIN            M  Bronze
# FIN            M    Gold

# %%
data['Medal'].value_counts()
# Out:
# Gold      774
# Silver    773
# Bronze    764
# Name: Medal, dtype: int64

# %%
data.groupby(['Sport','Discipline']).count()
# Out:
#                             Year  City  NOC  Event  Event gender  Medal
# Sport      Discipline
# Biathlon   Biathlon          162   162  162    162           162    162
# Bobsleigh  Bobsleigh         115   115  115    115           115    115
#            Skeleton           18    18   18     18            18     18
# Curling    Curling            21    21   21     21            21     21
# Ice Hockey Ice Hockey         69    69   69     69            69     69
# Luge       Luge              108   108  108    108           108    108
# Skating    Figure skating    207   207  207    207           207    207
#            Short Track S.     96    96   96     96            96     96
#            Speed skating     455   455  455    455           455    455
# Skiing     Alpine Skiing     367   367  367    367           367    367
#            Cross Country S   399   399  399    399           399    399
#            Freestyle Ski.     54    54   54     54            54     54
#            Nordic Combined    84    84   84     84            84     84
#            Ski Jumping       114   114  114    114           114    114
#            Snowboard          42    42   42     42            42     42

# %%
dataframe
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# 4               M    Gold
# ...           ...     ...
# 2306            M  Silver
# 2307            W    Gold
# 2308            W  Silver
# 2309            M    Gold
# 2310            W  Silver
#
# [2311 rows x 8 columns]

# %%
data
# Out:
#      Year      City       Sport      Discipline  NOC            Event  \
# NOC
# AUT  1924  Chamonix     Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix     Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix     Skating  Figure skating  AUT            pairs
# BEL  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# CAN  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ..    ...       ...         ...             ...  ...              ...
# USA  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# USA  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# USA  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# USA  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# USA  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#     Event gender   Medal
# NOC
# AUT            M  Silver
# AUT            W    Gold
# AUT            X    Gold
# BEL            M  Bronze
# CAN            M    Gold
# ..           ...     ...
# USA            M  Silver
# USA            W    Gold
# USA            W  Silver
# USA            M    Gold
# USA            W  Silver
#
# [2311 rows x 8 columns]
